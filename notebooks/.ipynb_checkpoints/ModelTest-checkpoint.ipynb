# %%
from model import createGenModel, createDiscModel
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-5-318f0f6f40e5> in <module>()
# ----> 1 from model import createGenModel, createDiscModel
#
# /home/rahool/Desktop/AnimeGen/model.py in <module>()
# ----> 1 from keras.layers import Conv2D, Conv2DTranspose, Concatenate, BatchNormalization, Input, MaxPooling2D, UpSampling2D, LeakyReLU, Activation
#       2 from keras.models import Model
#       3
#       4 # Model Creater Helper Func
#       5 # Helper For 1st half
#
# ImportError: No module named keras.layers

# %%
model = createModel()
model.summary()
# Out:
# WARNING:tensorflow:From E:\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            (None, 64, 64, 3)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 64, 64, 64)   832         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 64, 64, 64)   256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# ...
